# %%
import pandas as pd

# %%
df = pd.read_csv('data/ds_nhanvien.csv')
df
# Out:
#   Hoten Gioitinh   Vitri   Noisinh
# 0   NVA      Nam   first    Tp.HCM
# 1  LTVB       Nu   third  Dong Nai
# 2   NVC      Nam  second   Long An

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df['Vitri_encode'] = encoder.fit_transform(df['Vitri'])

# %%
df
# Out:
#   Hoten Gioitinh   Vitri   Noisinh  Vitri_encode
# 0   NVA      Nam   first    Tp.HCM             0
# 1  LTVB       Nu   third  Dong Nai             2
# 2   NVC      Nam  second   Long An             1

# %%
df2 = pd.read_csv('data/ds_nhanvien.csv')

# %%
df2
# Out:
#   Hoten Gioitinh   Vitri   Noisinh
# 0   NVA      Nam   first    Tp.HCM
# 1  LTVB       Nu   third  Dong Nai
# 2   NVC      Nam  second   Long An

# %%
df2 = df2.append({"Hoten": "LTD", "Gioitinh": "Nu", "Vitri": "fourth", "Noisinh": "Binh Duong"}, ignore_index= True)
df2
# Out:
#   Hoten Gioitinh   Vitri     Noisinh
# 0   NVA      Nam   first      Tp.HCM
# 1  LTVB       Nu   third    Dong Nai
# 2   NVC      Nam  second     Long An
# 3   LTD       Nu  fourth  Binh Duong

# %%
df2['Vitri_encode'] = encoder.fit_transform(df2['Vitri'])

# %%
df2
# Out:
#   Hoten Gioitinh   Vitri     Noisinh  Vitri_encode
# 0   NVA      Nam   first      Tp.HCM             0
# 1  LTVB       Nu   third    Dong Nai             3
# 2   NVC      Nam  second     Long An             2
# 3   LTD       Nu  fourth  Binh Duong             1

# %%
df2['Vitri2'] = ['1st', '3rd', '2nd', '4th']
df2
# Out:
#   Hoten Gioitinh   Vitri     Noisinh  Vitri_encode Vitri2
# 0   NVA      Nam   first      Tp.HCM             0    1st
# 1  LTVB       Nu   third    Dong Nai             3    3rd
# 2   NVC      Nam  second     Long An             2    2nd
# 3   LTD       Nu  fourth  Binh Duong             1    4th

# %%
df2['Vitri_encode2'] = encoder.fit_transform(df2['Vitri2'])
df2
# Out:
#   Hoten Gioitinh   Vitri     Noisinh  Vitri_encode Vitri2  Vitri_encode2
# 0   NVA      Nam   first      Tp.HCM             0    1st              0
# 1  LTVB       Nu   third    Dong Nai             3    3rd              2
# 2   NVC      Nam  second     Long An             2    2nd              1
# 3   LTD       Nu  fourth  Binh Duong             1    4th              3

# %%
df2['Vitri2_decode'] = encoder.inverse_transform(df2['Vitri_encode2'])

# %%
df2
# Out:
#   Hoten Gioitinh   Vitri     Noisinh  Vitri_encode Vitri2  Vitri_encode2  \
# 0   NVA      Nam   first      Tp.HCM             0    1st              0
# 1  LTVB       Nu   third    Dong Nai             3    3rd              2
# 2   NVC      Nam  second     Long An             2    2nd              1
# 3   LTD       Nu  fourth  Binh Duong             1    4th              3
#
#   Vitri2_decode
# 0           1st
# 1           3rd
# 2           2nd
# 3           4th

# %%
df2['Noisinh_encode'] = encoder.fit_transform(df2['Noisinh'])
df2
# Out:
#   Hoten Gioitinh   Vitri     Noisinh  Vitri_encode Vitri2  Vitri_encode2  \
# 0   NVA      Nam   first      Tp.HCM             0    1st              0
# 1  LTVB       Nu   third    Dong Nai             3    3rd              2
# 2   NVC      Nam  second     Long An             2    2nd              1
# 3   LTD       Nu  fourth  Binh Duong             1    4th              3
#
#   Vitri2_decode  Noisinh_encode
# 0           1st               3
# 1           3rd               1
# 2           2nd               2
# 3           4th               0
